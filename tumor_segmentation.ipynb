# %% [markdown]
# <a href="https://colab.research.google.com/github/Manith-2001/tumor_segmentation/blob/main/tumor_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.axes_grid1 import ImageGrid

import cv2
from glob import glob

import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D
from tensorflow.keras.layers import Conv2DTranspose, MaxPooling2D, concatenate, AveragePooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMAGE_SIZE = (256, 256)

# %%
image_path = list()
mask_path = list()
for i in sorted(os.listdir('../input/brain-tumor-segmentation/images/images')):
    image_path.append('../input/brain-tumor-segmentation/images/images/' + i)
for i in sorted(os.listdir('../input/brain-tumor-segmentation/masks/masks')):
    mask_path.append('../input/brain-tumor-segmentation/masks/masks/' + i)
df = pd.DataFrame()
df['image_path'] = image_path
df['mask_path'] = mask_path

# %%
df.head()
# Out:
#                                           image_path  \
# 0  ../input/brain-tumor-segmentation/images/image...
# 1  ../input/brain-tumor-segmentation/images/image...
# 2  ../input/brain-tumor-segmentation/images/image...
# 3  ../input/brain-tumor-segmentation/images/image...
# 4  ../input/brain-tumor-segmentation/images/image...
#
#                                            mask_path
# 0  ../input/brain-tumor-segmentation/masks/masks/...
# 1  ../input/brain-tumor-segmentation/masks/masks/...
# 2  ../input/brain-tumor-segmentation/masks/masks/...
# 3  ../input/brain-tumor-segmentation/masks/masks/...
# 4  ../input/brain-tumor-segmentation/masks/masks/...

# %%
df_positive = df.sample(5).values


def show_data(df, positive=True):
    images = []
    masks = []
    for data in df:
        img = cv2.imread(data[0])
        mask = cv2.imread(data[1])
        images.append(img)
        masks.append(mask)
    images = np.hstack(np.array(images))
    masks = np.hstack(np.array(masks))
    
    fig = plt.figure(figsize=(25,25))
    if positive:
        grid = ImageGrid(fig, 111, nrows_ncols=(3,1), axes_pad=0.5)
    else:
        grid = ImageGrid(fig, 111, nrows_ncols=(2,1), axes_pad=0.5)
    grid[0].imshow(images)
    grid[0].set_title('Images', fontsize=15)
    grid[0].axis('off')
    grid[1].imshow(masks)
    grid[1].set_title('Masks', fontsize=15)
    grid[1].axis('off')
    if positive:
        grid[2].imshow(images)
        grid[2].imshow(masks, alpha=0.4)
        grid[2].set_title('Brain MRI with mask', fontsize=15)
        grid[2].axis('off')
        
show_data(df_positive)

# %%
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.15)
df_train, df_val = train_test_split(df_train, test_size=0.15)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2838, 2)
# (501, 2)
# (590, 2)

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "image_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255.
    mask = mask / 255.
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred)
    return (2.0 * intersection + smooth) / (union + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy(from_logits=True)
    return dice_coef_loss(y_true, y_pred) + bce(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
EPOCHS = 100
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.1,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=IMAGE_SIZE)
    
val_gen = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=IMAGE_SIZE)
    
model = unet(input_size=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))



opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, amsgrad=False)
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brainMRI_seg.hdf5', verbose=0, save_best_only=True),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_lr=1e-11),
            EarlyStopping(monitor='val_loss', restore_best_weights=True, patience=15)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = val_gen,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# 2021-10-27 05:13:44.224889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:44.316866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:44.317605: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:44.318969: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-27 05:13:44.320083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:44.321013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:44.321889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:46.249046: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:46.249878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:46.250533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-27 05:13:46.251102: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Found 2838 validated image filenames.
# Found 2838 validated image filenames.
# 2021-10-27 05:13:58.811647: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# /opt/conda/lib/python3.7/site-packages/keras/backend.py:4994: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 2021-10-27 05:14:02.352473: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 89/88 [==============================] - ETA: 0s - loss: 1.1453 - iou: 0.0416 - dice_coef: 0.0789Found 501 validated image filenames.
# Found 501 validated image filenames.
# 88/88 [==============================] - 142s 1s/step - loss: 1.1453 - iou: 0.0416 - dice_coef: 0.0789 - val_loss: 1.5095 - val_iou: 0.0109 - val_dice_coef: 0.0215
# Epoch 2/100
# 88/88 [==============================] - 85s 956ms/step - loss: 0.9654 - iou: 0.0790 - dice_coef: 0.1449 - val_loss: 1.2917 - val_iou: 0.0121 - val_dice_coef: 0.0236
# Epoch 3/100
# 88/88 [==============================] - 83s 937ms/step - loss: 0.8949 - iou: 0.1066 - dice_coef: 0.1905 - val_loss: 1.1122 - val_iou: 0.0177 - val_dice_coef: 0.0342
# Epoch 4/100
# 88/88 [==============================] - 85s 958ms/step - loss: 0.8347 - iou: 0.1354 - dice_coef: 0.2352 - val_loss: 0.9559 - val_iou: 0.0685 - val_dice_coef: 0.1259
# Epoch 5/100
# 88/88 [==============================] - 83s 939ms/step - loss: 0.7813 - iou: 0.1642 - dice_coef: 0.2775 - val_loss: 0.8422 - val_iou: 0.1318 - val_dice_coef: 0.2279
# Epoch 6/100
# 88/88 [==============================] - 83s 942ms/step - loss: 0.7160 - iou: 0.2027 - dice_coef: 0.3323 - val_loss: 0.7061 - val_iou: 0.2066 - val_dice_coef: 0.3374
# Epoch 7/100
# 88/88 [==============================] - 83s 933ms/step - loss: 0.6629 - iou: 0.2378 - dice_coef: 0.3791 - val_loss: 0.6532 - val_iou: 0.2428 - val_dice_coef: 0.3860
# Epoch 8/100
# 88/88 [==============================] - 82s 932ms/step - loss: 0.5945 - iou: 0.2867 - dice_coef: 0.4405 - val_loss: 0.5890 - val_iou: 0.2938 - val_dice_coef: 0.4465
# Epoch 9/100
# 88/88 [==============================] - 82s 932ms/step - loss: 0.5402 - iou: 0.3299 - dice_coef: 0.4901 - val_loss: 0.4995 - val_iou: 0.3644 - val_dice_coef: 0.5300
# Epoch 10/100
# 88/88 [==============================] - 82s 929ms/step - loss: 1.0081 - iou: 0.0349 - dice_coef: 0.0638 - val_loss: 1.0280 - val_iou: 0.0138 - val_dice_coef: 0.0241
# Epoch 11/100
# 88/88 [==============================] - 83s 940ms/step - loss: 0.5280 - iou: 0.3458 - dice_coef: 0.5032 - val_loss: 0.5804 - val_iou: 0.3000 - val_dice_coef: 0.4497
# Epoch 12/100
# 88/88 [==============================] - 84s 950ms/step - loss: 0.4402 - iou: 0.4202 - dice_coef: 0.5842 - val_loss: 0.5014 - val_iou: 0.3634 - val_dice_coef: 0.5233
# Epoch 13/100
# 88/88 [==============================] - 83s 940ms/step - loss: 0.4154 - iou: 0.4446 - dice_coef: 0.6094 - val_loss: 0.4546 - val_iou: 0.4090 - val_dice_coef: 0.5697
# Epoch 14/100
# 88/88 [==============================] - 83s 938ms/step - loss: 0.3578 - iou: 0.5049 - dice_coef: 0.6635 - val_loss: 0.3956 - val_iou: 0.4670 - val_dice_coef: 0.6275
# Epoch 15/100
# 88/88 [==============================] - 82s 932ms/step - loss: 0.3194 - iou: 0.5447 - dice_coef: 0.7003 - val_loss: 0.3465 - val_iou: 0.5139 - val_dice_coef: 0.6745
# Epoch 16/100
# 88/88 [==============================] - 83s 944ms/step - loss: 0.3019 - iou: 0.5661 - dice_coef: 0.7176 - val_loss: 0.2931 - val_iou: 0.5741 - val_dice_coef: 0.7238
# Epoch 17/100
# 88/88 [==============================] - 83s 943ms/step - loss: 0.3004 - iou: 0.5704 - dice_coef: 0.7206 - val_loss: 0.3042 - val_iou: 0.5628 - val_dice_coef: 0.7173
# Epoch 18/100
# 88/88 [==============================] - 83s 934ms/step - loss: 0.9160 - iou: 0.0966 - dice_coef: 0.1561 - val_loss: 0.9824 - val_iou: 0.0374 - val_dice_coef: 0.0684
# Epoch 19/100
# 88/88 [==============================] - 81s 920ms/step - loss: 1.0170 - iou: 0.0222 - dice_coef: 0.0419 - val_loss: 0.9106 - val_iou: 0.0685 - val_dice_coef: 0.1257
# Epoch 20/100
# 88/88 [==============================] - 83s 936ms/step - loss: 0.3157 - iou: 0.5598 - dice_coef: 0.7039 - val_loss: 0.3347 - val_iou: 0.5287 - val_dice_coef: 0.6854
# Epoch 21/100
# 88/88 [==============================] - 82s 923ms/step - loss: 0.2460 - iou: 0.6346 - dice_coef: 0.7718 - val_loss: 0.2752 - val_iou: 0.5914 - val_dice_coef: 0.7404
# Epoch 22/100
# 88/88 [==============================] - 82s 928ms/step - loss: 0.2427 - iou: 0.6403 - dice_coef: 0.7748 - val_loss: 0.2511 - val_iou: 0.6252 - val_dice_coef: 0.7676
# Epoch 23/100
# 88/88 [==============================] - 82s 930ms/step - loss: 0.2276 - iou: 0.6593 - dice_coef: 0.7890 - val_loss: 0.2611 - val_iou: 0.6161 - val_dice_coef: 0.7496
# Epoch 24/100
# 88/88 [==============================] - 83s 933ms/step - loss: 0.2183 - iou: 0.6729 - dice_coef: 0.7986 - val_loss: 0.2818 - val_iou: 0.5967 - val_dice_coef: 0.7360
# Epoch 25/100
# 88/88 [==============================] - 83s 941ms/step - loss: 0.2445 - iou: 0.6414 - dice_coef: 0.7761 - val_loss: 0.4110 - val_iou: 0.4746 - val_dice_coef: 0.6358
# Epoch 26/100
# 88/88 [==============================] - 81s 920ms/step - loss: 0.2180 - iou: 0.6735 - dice_coef: 0.8002 - val_loss: 0.2415 - val_iou: 0.6430 - val_dice_coef: 0.7784
# Epoch 27/100
# 88/88 [==============================] - 82s 929ms/step - loss: 0.2051 - iou: 0.6916 - dice_coef: 0.8111 - val_loss: 0.1991 - val_iou: 0.6927 - val_dice_coef: 0.8158
# Epoch 28/100
# 88/88 [==============================] - 82s 925ms/step - loss: 0.1911 - iou: 0.7099 - dice_coef: 0.8249 - val_loss: 0.2068 - val_iou: 0.6787 - val_dice_coef: 0.8052
# Epoch 29/100
# 88/88 [==============================] - 82s 928ms/step - loss: 0.1881 - iou: 0.7134 - dice_coef: 0.8275 - val_loss: 0.1983 - val_iou: 0.6999 - val_dice_coef: 0.8207
# Epoch 30/100
# 88/88 [==============================] - 83s 933ms/step - loss: 0.1850 - iou: 0.7166 - dice_coef: 0.8310 - val_loss: 0.1868 - val_iou: 0.7093 - val_dice_coef: 0.8268
# Epoch 31/100
# 88/88 [==============================] - 83s 933ms/step - loss: 0.1815 - iou: 0.7214 - dice_coef: 0.8334 - val_loss: 0.1970 - val_iou: 0.7012 - val_dice_coef: 0.8213
# Epoch 32/100
# 88/88 [==============================] - 82s 932ms/step - loss: 1.0304 - iou: 0.0232 - dice_coef: 0.0434 - val_loss: 1.0417 - val_iou: 0.0178 - val_dice_coef: 0.0302
# Epoch 33/100
# 88/88 [==============================] - 82s 930ms/step - loss: 0.2022 - iou: 0.6993 - dice_coef: 0.8138 - val_loss: 0.1989 - val_iou: 0.7009 - val_dice_coef: 0.8203
# Epoch 34/100
# 88/88 [==============================] - 83s 933ms/step - loss: 0.8512 - iou: 0.1538 - dice_coef: 0.2339 - val_loss: 0.7231 - val_iou: 0.1809 - val_dice_coef: 0.3026
# Epoch 35/100
# 88/88 [==============================] - 82s 928ms/step - loss: 0.2196 - iou: 0.6770 - dice_coef: 0.7963 - val_loss: 0.2678 - val_iou: 0.6121 - val_dice_coef: 0.7527
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 36/100
# 88/88 [==============================] - 82s 928ms/step - loss: 0.1625 - iou: 0.7474 - dice_coef: 0.8525 - val_loss: 0.1797 - val_iou: 0.7245 - val_dice_coef: 0.8369
# Epoch 37/100
# 88/88 [==============================] - 84s 945ms/step - loss: 0.1601 - iou: 0.7512 - dice_coef: 0.8544 - val_loss: 0.1656 - val_iou: 0.7390 - val_dice_coef: 0.8483
# Epoch 38/100
# 88/88 [==============================] - 82s 929ms/step - loss: 0.1572 - iou: 0.7550 - dice_coef: 0.8567 - val_loss: 0.1701 - val_iou: 0.7346 - val_dice_coef: 0.8438
# Epoch 39/100
# 88/88 [==============================] - 83s 935ms/step - loss: 0.1511 - iou: 0.7619 - dice_coef: 0.8620 - val_loss: 0.1820 - val_iou: 0.7163 - val_dice_coef: 0.8298
# Epoch 40/100
# 88/88 [==============================] - 82s 929ms/step - loss: 0.1532 - iou: 0.7600 - dice_coef: 0.8599 - val_loss: 0.1817 - val_iou: 0.7167 - val_dice_coef: 0.8330
# Epoch 41/100
# 88/88 [==============================] - 83s 936ms/step - loss: 0.1526 - iou: 0.7609 - dice_coef: 0.8606 - val_loss: 0.1672 - val_iou: 0.7394 - val_dice_coef: 0.8482
# Epoch 42/100
# 88/88 [==============================] - 83s 934ms/step - loss: 0.8473 - iou: 0.1609 - dice_coef: 0.2457 - val_loss: 0.2323 - val_iou: 0.6421 - val_dice_coef: 0.7793
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 43/100
# 88/88 [==============================] - 83s 935ms/step - loss: 1.0443 - iou: 0.0228 - dice_coef: 0.0407 - val_loss: 0.3273 - val_iou: 0.5338 - val_dice_coef: 0.6906
# Epoch 44/100
# 88/88 [==============================] - 84s 949ms/step - loss: 0.2289 - iou: 0.6540 - dice_coef: 0.7834 - val_loss: 0.1991 - val_iou: 0.6901 - val_dice_coef: 0.8127
# Epoch 45/100
# 88/88 [==============================] - 83s 940ms/step - loss: 0.1693 - iou: 0.7329 - dice_coef: 0.8410 - val_loss: 0.1867 - val_iou: 0.7086 - val_dice_coef: 0.8265
# Epoch 46/100
# 88/88 [==============================] - 83s 937ms/step - loss: 0.1603 - iou: 0.7446 - dice_coef: 0.8500 - val_loss: 0.1816 - val_iou: 0.7164 - val_dice_coef: 0.8320
# Epoch 47/100
# 88/88 [==============================] - 83s 938ms/step - loss: 0.1546 - iou: 0.7536 - dice_coef: 0.8559 - val_loss: 0.1699 - val_iou: 0.7277 - val_dice_coef: 0.8412
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
# Epoch 48/100
# 88/88 [==============================] - 84s 945ms/step - loss: 0.1579 - iou: 0.7512 - dice_coef: 0.8535 - val_loss: 0.1709 - val_iou: 0.7313 - val_dice_coef: 0.8426
# Epoch 49/100
# 88/88 [==============================] - 83s 934ms/step - loss: 0.1576 - iou: 0.7508 - dice_coef: 0.8532 - val_loss: 0.1733 - val_iou: 0.7298 - val_dice_coef: 0.8401
# Epoch 50/100
# 88/88 [==============================] - 83s 942ms/step - loss: 1.0101 - iou: 0.0623 - dice_coef: 0.1070 - val_loss: 0.1588 - val_iou: 0.7416 - val_dice_coef: 0.8497
# Epoch 51/100
# 88/88 [==============================] - 83s 936ms/step - loss: 0.1565 - iou: 0.7527 - dice_coef: 0.8545 - val_loss: 0.1844 - val_iou: 0.7152 - val_dice_coef: 0.8270
# Epoch 52/100
# 88/88 [==============================] - 84s 950ms/step - loss: 0.1570 - iou: 0.7529 - dice_coef: 0.8543 - val_loss: 0.2007 - val_iou: 0.6879 - val_dice_coef: 0.8110
# Epoch 53/100
# 88/88 [==============================] - 82s 931ms/step - loss: 0.1531 - iou: 0.7571 - dice_coef: 0.8579 - val_loss: 0.1693 - val_iou: 0.7347 - val_dice_coef: 0.8447
# Epoch 54/100
# 88/88 [==============================] - 84s 952ms/step - loss: 0.1546 - iou: 0.7553 - dice_coef: 0.8570 - val_loss: 0.1801 - val_iou: 0.7170 - val_dice_coef: 0.8329
# Epoch 55/100
# 88/88 [==============================] - 85s 960ms/step - loss: 1.0828 - iou: 0.0247 - dice_coef: 0.0446 - val_loss: 0.1652 - val_iou: 0.7374 - val_dice_coef: 0.8468
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
# Epoch 56/100
# 88/88 [==============================] - 84s 946ms/step - loss: 0.1531 - iou: 0.7564 - dice_coef: 0.8581 - val_loss: 0.1826 - val_iou: 0.7198 - val_dice_coef: 0.8293
# Epoch 57/100
# 88/88 [==============================] - 84s 948ms/step - loss: 0.1591 - iou: 0.7481 - dice_coef: 0.8520 - val_loss: 0.1579 - val_iou: 0.7471 - val_dice_coef: 0.8541
# Epoch 58/100
# 88/88 [==============================] - 84s 951ms/step - loss: 0.1561 - iou: 0.7531 - dice_coef: 0.8545 - val_loss: 0.1895 - val_iou: 0.7056 - val_dice_coef: 0.8236
# Epoch 59/100
# 88/88 [==============================] - 84s 947ms/step - loss: 0.9042 - iou: 0.1294 - dice_coef: 0.1999 - val_loss: 0.1729 - val_iou: 0.7283 - val_dice_coef: 0.8394
# Epoch 60/100
# 88/88 [==============================] - 83s 939ms/step - loss: 0.1563 - iou: 0.7533 - dice_coef: 0.8543 - val_loss: 0.1634 - val_iou: 0.7393 - val_dice_coef: 0.8482
# Epoch 61/100
# 88/88 [==============================] - 83s 937ms/step - loss: 0.1573 - iou: 0.7504 - dice_coef: 0.8536 - val_loss: 0.1775 - val_iou: 0.7206 - val_dice_coef: 0.8348
# Epoch 62/100
# 88/88 [==============================] - 83s 941ms/step - loss: 0.1550 - iou: 0.7556 - dice_coef: 0.8561 - val_loss: 0.1775 - val_iou: 0.7218 - val_dice_coef: 0.8347
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
# Epoch 63/100
# 88/88 [==============================] - 83s 941ms/step - loss: 0.1535 - iou: 0.7573 - dice_coef: 0.8580 - val_loss: 0.1594 - val_iou: 0.7474 - val_dice_coef: 0.8542
# Epoch 64/100
# 88/88 [==============================] - 84s 946ms/step - loss: 0.1561 - iou: 0.7526 - dice_coef: 0.8551 - val_loss: 0.1685 - val_iou: 0.7337 - val_dice_coef: 0.8437
# Epoch 65/100
# 88/88 [==============================] - 83s 937ms/step - loss: 0.1595 - iou: 0.7508 - dice_coef: 0.8527 - val_loss: 0.1688 - val_iou: 0.7323 - val_dice_coef: 0.8426
# Epoch 66/100
# 88/88 [==============================] - 84s 952ms/step - loss: 0.1525 - iou: 0.7575 - dice_coef: 0.8587 - val_loss: 0.1669 - val_iou: 0.7371 - val_dice_coef: 0.8461
# Epoch 67/100
# 88/88 [==============================] - 83s 936ms/step - loss: 0.1555 - iou: 0.7539 - dice_coef: 0.8555 - val_loss: 0.1642 - val_iou: 0.7411 - val_dice_coef: 0.8490
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
# Epoch 68/100
# 88/88 [==============================] - 84s 955ms/step - loss: 1.0771 - iou: 0.0265 - dice_coef: 0.0481 - val_loss: 0.1662 - val_iou: 0.7331 - val_dice_coef: 0.8447
# Epoch 69/100
# 88/88 [==============================] - 83s 944ms/step - loss: 0.1526 - iou: 0.7576 - dice_coef: 0.8587 - val_loss: 0.1603 - val_iou: 0.7407 - val_dice_coef: 0.8490
# Epoch 70/100
# 88/88 [==============================] - 85s 960ms/step - loss: 0.1558 - iou: 0.7540 - dice_coef: 0.8553 - val_loss: 0.1730 - val_iou: 0.7245 - val_dice_coef: 0.8384
# Epoch 71/100
# 88/88 [==============================] - 83s 941ms/step - loss: 0.1562 - iou: 0.7524 - dice_coef: 0.8549 - val_loss: 0.1794 - val_iou: 0.7193 - val_dice_coef: 0.8340
# Epoch 72/100
# 88/88 [==============================] - 86s 976ms/step - loss: 0.1616 - iou: 0.7486 - dice_coef: 0.8504 - val_loss: 0.1725 - val_iou: 0.7283 - val_dice_coef: 0.8404
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1e-11.

# %%
plt.figure(figsize=(8,15))
plt.subplot(3,1,1)
plt.plot(model.history.history['loss'], 'b-', label='train_loss')
plt.plot(model.history.history['val_loss'], 'r-', label='val_loss')
plt.legend(loc='best')
plt.title('Loss')

plt.subplot(3,1,2)
plt.plot(model.history.history['iou'], 'b-', label='train_iou')
plt.plot(model.history.history['val_iou'], 'r-', label='val_iou')
plt.legend(loc='best')
plt.title('IoU')

plt.subplot(3,1,3)
plt.plot(model.history.history['dice_coef'], 'b-', label='train_dice_coef')
plt.plot(model.history.history['val_dice_coef'], 'r-', label='val_dice_coef')
plt.legend(loc='best')
plt.title('Dice Coef')
# Out:
# Text(0.5, 1.0, 'Dice Coef')

# %%
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=IMAGE_SIZE)
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 590 validated image filenames.
# Found 590 validated image filenames.
# 18/18 [==============================] - 12s 648ms/step - loss: 0.1516 - iou: 0.7535 - dice_coef: 0.8579
# Test IOU:  0.7535183429718018
# Test Dice Coefficent:  0.8578742146492004

# %%
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['image_path'].iloc[index])
    img = cv2.resize(img ,IMAGE_SIZE)
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask_path'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
